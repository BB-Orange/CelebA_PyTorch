# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 指定したパスからディレクトリ情報のみ抜き出して出力する。
import os
path = '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train'
files = os.listdir(path=path)
folder = [f for f in files if os.path.isdir(os.path.join(path, f))]
print(folder)
# Out:
# ['NakedEye_Woman_NoHat', 'NakedEye_Woman_Hat', 'NakedEye_Man_Hat', 'NakedEye_Man_NoHat', 'Glass_Woman_NoHat', 'Glass_Woman_Hat', 'Glass_Man_NoHat', 'Glass_Man_Hat']

# %%
import json
# ラベル用リストの作成
path = '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train'
files = os.listdir(path=path)
FolderList = [f for f in files if os.path.isdir(os.path.join(path, f))]
print(FolderList)

ILSVRC_class_index = json.load(open('/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/imagenet_class_index.json', 'r'))
print(ILSVRC_class_index)
print(ILSVRC_class_index['0'][1])

for folder in ILSVRC_class_index:
  print(ILSVRC_class_index[str(folder)][1])
# Out:
# ['NakedEye_Woman_NoHat', 'NakedEye_Woman_Hat', 'NakedEye_Man_Hat', 'NakedEye_Man_NoHat', 'Glass_Woman_NoHat', 'Glass_Woman_Hat', 'Glass_Man_NoHat', 'Glass_Man_Hat']
# {'0': ['n01440764', 'Glass_Man_Hat'], '1': ['n01443537', 'Glass_Man_NoHat'], '2': ['n01484850', 'Glass_Woman_Hat'], '3': ['n01491361', 'Glass_Woman_NoHat'], '4': ['n01494475', 'NakedEye_Man_Hat'], '5': ['n01496331', 'NakedEye_Man_NoHat'], '6': ['n01498041', 'NakedEye_Woman_Hat'], '7': ['n01514668', 'NakedEye_Woman_NoHat']}
# Glass_Man_Hat
# Glass_Man_Hat
# Glass_Man_NoHat
# Glass_Woman_Hat
# Glass_Woman_NoHat
# NakedEye_Man_Hat
# NakedEye_Man_NoHat
# NakedEye_Woman_Hat
# NakedEye_Woman_NoHat

# %% [markdown]
# VGG16学習済モデルでCelebAを使用したファインチューニング（8クラス）

# %%
# パッケージのimport
import glob
import os.path as osp
import random
import numpy as np
import json
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision
from torchvision import models, transforms
import torchvision.datasets as datasets

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# Datasetを作成

# %%
# 入力画像の前処理をするクラス
# 訓練時と推論時で処理が異なる


class ImageTransform():
    """
    画像の前処理クラス。訓練時、検証時で異なる動作をする。
    画像のサイズをリサイズし、色を標準化する。
    訓練時はRandomResizedCropとRandomHorizontalFlipでデータオーギュメンテーションする。


    Attributes
    ----------
    resize : int
        リサイズ先の画像の大きさ。
    mean : (R, G, B)
        各色チャネルの平均値。
    std : (R, G, B)
        各色チャネルの標準偏差。
    """

    def __init__(self, resize, mean, std):
        self.data_transform = {
            'train': transforms.Compose([
                transforms.RandomResizedCrop(
                    resize, scale=(0.5, 1.0)),  # データオーギュメンテーション
                transforms.RandomHorizontalFlip(),  # データオーギュメンテーション
                transforms.ToTensor(),  # テンソルに変換
                transforms.Normalize(mean, std)  # 標準化
            ]),
            'val': transforms.Compose([
                transforms.Resize(resize),  # リサイズ
                transforms.CenterCrop(resize),  # 画像中央をresize×resizeで切り取り
                transforms.ToTensor(),  # テンソルに変換
                transforms.Normalize(mean, std)  # 標準化
            ])
        }

    def __call__(self, img, phase='train'):
        """
        Parameters
        ----------
        phase : 'train' or 'val'
            前処理のモードを指定。
        """
        return self.data_transform[phase](img)

# %%
# セレブ画像へのファイルパスのリストを作成する
def make_datapath_list(phase="train"):
    """
    データのパスを格納したリストを作成する。

    Parameters
    ----------
    phase : 'train' or 'val'
        訓練データか検証データかを指定する

    Returns
    -------
    path_list : list
        データへのパスを格納したリスト
    """

    rootpath = '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/'
    target_path = osp.join(rootpath + phase + '/**/*.png')
    print(target_path)

    path_list = []  # ここに格納する

    # globを利用してサブディレクトリまでファイルパスを取得する
    for path in glob.glob(target_path):
        path_list.append(path)

    return path_list

# 実行
train_list = make_datapath_list(phase="train")
val_list = make_datapath_list(phase="val")

train_list
# Out:
# /content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/**/*.png
# /content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/val/**/*.png
# ['/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000001.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000004.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000058.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000071.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000039.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000075.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000045.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000087.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000066.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000019.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000098.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000028.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000084.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000089.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000086.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000059.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000054.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000022.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000042.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000062.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000046.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000043.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000077.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000034.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000044.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000057.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000026.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000097.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000024.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000096.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000040.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000031.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000078.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000018.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000083.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000092.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000085.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000063.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000035.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000088.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000073.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000047.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000094.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000027.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000029.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000141.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000165.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000110.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000148.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000131.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000107.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000103.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000133.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000162.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000147.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000145.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000112.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000146.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000155.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000157.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000118.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000106.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000151.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000126.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000142.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000108.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000156.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000139.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000132.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000121.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000101.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000111.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000163.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000117.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000122.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000099.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000124.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000140.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000100.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000159.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000161.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000128.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000183.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000175.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000201.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000184.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000186.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000218.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000219.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000225.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000239.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000170.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000232.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000176.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000179.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000167.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000190.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000177.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000228.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000208.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000207.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000233.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000236.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000168.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000178.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000231.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000216.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000217.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000191.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000180.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000240.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000172.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000238.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000211.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000222.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000198.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000174.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000192.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000204.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000173.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000185.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000258.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000279.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000289.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000302.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000267.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000256.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000260.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000309.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000251.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000305.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000312.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000303.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000252.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000280.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000246.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000241.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000301.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000278.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000287.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000268.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000269.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000273.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000292.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000259.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000288.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000249.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000285.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000247.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000254.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000257.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000270.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000281.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000263.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000304.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000291.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000271.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000262.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000296.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000290.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000317.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000341.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000356.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000357.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000326.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000334.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000369.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000328.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000347.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000364.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000327.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000361.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000359.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000372.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000323.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000349.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000379.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000322.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000319.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000351.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000325.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000338.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000332.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000343.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000344.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000342.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000337.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000354.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000365.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000374.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000371.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000353.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000315.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000345.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000407.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000387.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000384.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000423.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000420.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000381.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000421.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000419.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000395.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000445.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000399.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000432.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000435.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000396.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000431.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000412.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000441.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000411.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000388.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000394.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000442.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000422.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000382.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000415.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000404.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000426.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000391.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000424.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000397.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000436.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000410.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000495.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000502.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000466.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000468.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000509.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000494.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000508.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000480.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000491.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000492.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000475.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000471.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000463.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000469.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000454.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000510.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000470.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000497.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000478.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000493.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000455.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000485.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000472.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000504.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000464.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000505.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000446.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000499.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000507.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000489.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000487.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000462.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000467.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000458.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000506.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000476.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000483.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000457.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000503.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000488.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000574.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000539.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000565.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000551.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000531.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000550.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000530.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000548.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000516.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000582.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000528.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000580.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000544.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000556.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000554.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000525.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000568.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000557.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000549.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000524.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000522.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000523.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000547.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000540.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000570.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000579.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000513.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000553.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000538.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000517.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000532.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000541.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000576.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000527.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000514.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000562.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000519.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000533.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000567.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000566.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000607.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000618.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000634.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000615.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000616.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000626.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000588.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000632.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000609.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000631.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000612.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000613.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000640.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000648.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000599.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000601.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000605.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000589.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000641.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000644.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000642.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000595.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000594.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000610.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000614.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000621.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000647.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000638.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000627.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000611.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000633.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000602.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000650.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000606.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000645.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000600.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000597.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000643.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000598.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000680.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000701.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000669.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000667.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000709.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000665.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000693.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000707.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000717.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000679.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000715.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000719.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000692.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000663.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000694.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000656.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000703.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000716.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000708.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000668.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000653.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000698.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000664.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000704.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000658.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000678.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000699.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000711.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000702.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000666.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000718.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000691.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000765.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000741.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000721.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000759.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000786.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000764.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000736.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000758.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000737.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000783.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000722.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000787.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000734.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000769.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000785.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000776.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000766.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000750.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000782.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000754.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000746.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000767.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000748.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000762.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000763.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000738.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000777.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000781.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000743.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000761.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000751.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000740.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000742.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000774.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000772.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000725.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000727.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000794.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000854.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000814.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000839.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000840.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000805.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000847.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000831.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000807.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000804.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000800.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000796.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000832.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000817.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000821.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000799.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000828.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000834.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000827.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000811.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000812.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000795.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000819.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000852.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000792.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000824.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000822.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000823.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000837.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000810.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000793.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000802.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000806.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000849.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000835.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000809.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000909.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000901.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000900.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000878.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000867.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000919.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000857.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000870.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000890.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000897.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000872.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000871.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000869.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000895.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000910.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000864.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000882.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000883.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000916.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000874.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000924.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000917.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000899.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000925.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000884.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000865.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000856.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000866.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/000914.png',
# ...
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001493.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001504.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001482.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001520.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001512.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001566.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001610.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001603.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001546.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001594.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001560.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001584.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001551.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001574.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001567.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001587.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001579.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001569.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001597.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001609.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001553.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001614.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001572.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001549.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001564.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001593.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001548.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001592.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001602.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001612.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001590.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001568.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001576.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001607.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001595.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001575.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001570.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001604.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001600.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001585.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001552.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001665.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001671.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001653.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001648.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001681.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001637.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001664.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001621.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001618.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001643.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001631.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001645.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001680.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001663.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001628.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001660.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001658.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001647.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001639.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001650.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001649.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001622.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001624.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001642.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001644.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001670.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001683.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001682.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001662.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001620.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001651.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001676.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001641.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001629.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001638.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001672.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001667.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001635.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001619.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001673.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001668.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001626.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001726.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001727.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001744.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001697.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001707.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001714.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001704.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001747.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001732.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001685.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001709.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001739.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001719.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001745.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001687.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001688.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001731.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001720.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001710.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001733.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001734.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001713.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001695.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001686.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001702.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001700.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001718.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001746.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001705.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001724.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001737.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001743.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001696.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001694.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001751.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001698.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001748.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001725.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001708.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001776.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001809.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001820.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001768.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001779.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001783.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001786.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001787.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001812.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001802.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001817.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001771.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001772.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001816.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001818.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001762.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001774.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001753.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001777.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001760.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001807.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001769.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001796.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001770.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001795.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001805.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001784.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001778.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001811.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001806.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001793.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001798.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001789.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001810.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001764.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001785.png',
#  '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/train/NakedEye_Woman_NoHat/001821.png',
#  ...]

# %%
def PathToLabel(label):
  i = 0
  for index in ILSVRC_class_index:
    if label == (ILSVRC_class_index[str(index)][1]):
      return i
    i += 1
  
  return -1
  
  '''
  for folder in ILSVRC_class_index:
    if folder[1] == label:
      return i
  '''

# %%
# セレブの画像のDatasetを作成する
class CelebDataset(data.Dataset):
    """
    アリとハチの画像のDatasetクラス。PyTorchのDatasetクラスを継承。

    Attributes
    ----------
    file_list : リスト
        画像のパスを格納したリスト
    transform : object
        前処理クラスのインスタンス
    phase : 'train' or 'test'
        学習か訓練かを設定する。
    """

    def __init__(self, file_list, transform=None, phase='train'):
        self.file_list = file_list  # ファイルパスのリスト
        self.transform = transform  # 前処理クラスのインスタンス
        self.phase = phase  # train or valの指定

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''
        前処理をした画像のTensor形式のデータとラベルを取得
        '''

        # index番目の画像をロード
        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅][色RGB]

        # 画像の前処理を実施
        img_transformed = self.transform(
            img, self.phase)  # torch.Size([3, 224, 224])

        # 画像のラベルをファイル名から抜き出す
        label = osp.basename(osp.dirname(img_path))
        # ラベルを数値に変更する
        label = PathToLabel(label)

        return img_transformed, label

# 実行
train_dataset = CelebDataset(
    file_list=train_list, transform=ImageTransform(size, mean, std), phase='train')

val_dataset = CelebDataset(
    file_list=val_list, transform=ImageTransform(size, mean, std), phase='val')

# 動作確認
index = 0
print(train_dataset.__getitem__(index)[0].size())
print(train_dataset.__getitem__(index)[1])
# Out:
# torch.Size([3, 224, 224])
# 7

# %% [markdown]
# DataLoaderを作成

# %%
# ミニバッチのサイズを指定
batch_size = 32

# DataLoaderを作成
train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False)

# 辞書型変数にまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# 動作確認
batch_iterator = iter(dataloaders_dict["train"])  # イテレータに変換
inputs, labels = next(
    batch_iterator)  # 1番目の要素を取り出す
print(inputs.size())
print(labels)
# Out:
# torch.Size([32, 3, 224, 224])
# tensor([7, 1, 6, 1, 4, 3, 5, 1, 4, 0, 1, 7, 5, 0, 1, 7, 5, 4, 4, 6, 3, 7, 4, 6,
#         7, 6, 6, 5, 6, 1, 0, 4])

# %% [markdown]
# ネットワークモデルの作成

# %%
# 学習済みのVGG-16モデルをロード
# VGG-16モデルのインスタンスを生成
use_pretrained = True  # 学習済みのパラメータを使用
net = models.vgg16(pretrained=use_pretrained)

# デバイスの選択（PyTorchがGPUを使用できるのであれば、GPUを使用するように）
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(torch.cuda.is_available())

# VGG16の最後の出力層の出力ユニットを8つに付け替える
net.classifier[6] = nn.Linear(in_features=4096, out_features=8)
net = net.to(device)  # GPUに転送

# 訓練モードに設定
net.train()

print('ネットワーク設定完了：学習済みの重みをロードし、訓練モードに設定しました')
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# True
# ネットワーク設定完了：学習済みの重みをロードし、訓練モードに設定しました

# %% [markdown]
# 損失関数を定義

# %%
# 損失関数の設定
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# 最適化手法の設定

# %%
# 転移学習で学習させるパラメータを、変数params_to_updateに格納する
params_to_update = []

# 学習させるパラメータ名
update_param_names = ["classifier.6.weight", "classifier.6.bias"]

# 学習させるパラメータ以外は勾配計算をなくし、変化しないように設定
for name, param in net.named_parameters():
    if name in update_param_names:
        param.requires_grad = True
        params_to_update.append(param)
        print(name)
    else:
        param.requires_grad = False

# params_to_updateの中身を確認
print("-----------")
print(params_to_update)
# Out:
# classifier.6.weight
# classifier.6.bias
# -----------
# [Parameter containing:
# tensor([[-0.0108, -0.0026,  0.0099,  ...,  0.0066, -0.0093,  0.0042],
#         [-0.0131,  0.0002, -0.0092,  ..., -0.0025, -0.0018, -0.0049],
#         [-0.0052, -0.0028, -0.0026,  ...,  0.0127,  0.0138, -0.0048],
#         ...,
#         [-0.0038, -0.0124, -0.0134,  ...,  0.0090, -0.0152, -0.0145],
#         [ 0.0070,  0.0054,  0.0107,  ...,  0.0040,  0.0070, -0.0049],
#         [-0.0067, -0.0081, -0.0146,  ..., -0.0074,  0.0096,  0.0029]],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0076,  0.0082, -0.0145,  0.0117, -0.0093, -0.0045,  0.0065, -0.0131],
#        requires_grad=True)]

# %%
# 最適化手法の設定
optimizer = optim.SGD(params=params_to_update, lr=0.001, momentum=0.9)

# %% [markdown]
# 学習と検証の実施

# %%
# モデルを学習させる関数を作成
def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # epochのループ
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの学習と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
            else:
                net.eval()   # モデルを検証モードに

            epoch_loss = 0.0  # epochの損失和
            epoch_corrects = 0  # epochの正解数

            # 未学習時の検証性能を確かめるため、epoch=0の訓練は省略
            if (epoch == 0) and (phase == 'train'):
                continue

            # データローダーからミニバッチを取り出すループ
            for inputs, labels in tqdm(dataloaders_dict[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = net(inputs)
                    loss = criterion(outputs, labels)  # 損失を計算
                    _, preds = torch.max(outputs, 1)  # ラベルを予測
                    
  
                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                    # イタレーション結果の計算
                    # lossの合計を更新
                    epoch_loss += loss.item() * inputs.size(0)  
                    # 正解数の合計を更新
                    epoch_corrects += torch.sum(preds == labels.data)

            # epochごとのlossと正解率を表示
            epoch_loss = epoch_loss / len(dataloaders_dict[phase].dataset)
            epoch_acc = epoch_corrects.double(
            ) / len(dataloaders_dict[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

# %%
# 学習・検証を実行する
num_epochs=3
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 1/3
# -------------
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-b2793ab078d8> in <module>
#       1 # 学習・検証を実行する
#       2 num_epochs=3
# ----> 3 train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
#
# <ipython-input-41-27746b182a7f> in train_model(net, dataloaders_dict, criterion, optimizer, num_epochs)
#      31                 # 順伝搬（forward）計算
#      32                 with torch.set_grad_enabled(phase == 'train'):
# ---> 33                     outputs = net(inputs)
#      34                     loss = criterion(outputs, labels)  # 損失を計算
#      35                     _, preds = torch.max(outputs, 1)  # ラベルを予測
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      67         x = self.avgpool(x)
#      68         x = torch.flatten(x, 1)
# ---> 69         x = self.classifier(x)
#      70         return x
#      71
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat1 in method wrapper_addmm)

# %%
# PyTorchのネットワークパラメータの保存
save_path = '/content/drive/MyDrive/Colab Notebooks/CelebA_8class/data/weights_teni.pth'

torch.save(net.state_dict(), save_path)
